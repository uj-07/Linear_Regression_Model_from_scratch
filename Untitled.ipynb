# %% [markdown]
# <a href="https://colab.research.google.com/github/uj-07/Linear_Regression_Model_from_scratch/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class LR:

    def __init__(self):
        """
        Initializes the Simple Linear Regression model.
        m: slope of the line
        b: y-intercept of the line
        """

        self.m = None
        self.b = None

    def fit(self,X_train,y_train):
        """
        Trains the model using the Closed-Form Solution (Ordinary Least Squares).

        Formula:
        m = sum((x - x_mean) * (y - y_mean)) / sum((x - x_mean)^2)
        b = y_mean - m * x_mean
        """

        num = 0
        den = 0

        # Calculate the numerator and denominator for the slope (m) formula

        for i in range(X_train.shape[0]):
            num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
            den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))

        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())
        print(self.m)
        print(self.b)

    def predict(self,X_test):
        """
        Predicts target values for the given test data.

        Equation: y = m * x + b
        """

        print(X_test)

        return self.m * X_test + self.b

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.shape
# Out:
# (30, 2)

# %%
X = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
X
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
plt.scatter(X_train, y_train)
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (24,)

# %%
X_test.shape
# Out:
# (6,)

# %%
y_train.shape
# Out:
# (24,)

# %%
lr = LR()

# %%
lr.fit(X_train,y_train)
# Out:
# 9569.586885432866
# 24393.169151948343

# %%
y_pred = lr.predict(X_test)
print(y_pred)
# Out:
# [1.3 1.1 4.5 3.7 7.1 6. ]
# [36833.63210301 34919.71472592 67456.3101364  59800.64062805
#  92337.23603852 81810.69046455]

# %%
# Create a DataFrame to visually compare actual vs predicted
comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(comparison_df)
# Out:
#     Actual     Predicted
# 0  46205.0  36833.632103
# 1  39343.0  34919.714726
# 2  61111.0  67456.310136
# 3  57189.0  59800.640628
# 4  98273.0  92337.236039
# 5  93940.0  81810.690465

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error


r2 = r2_score(y_test, y_pred)


mae = mean_absolute_error(y_test, y_pred)


rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"R2 Score (Variance Explained): {r2:.4f}")
print(f"Mean Absolute Error: ${mae:.2f}")
print(f"Root Mean Squared Error: ${rmse:.2f}")
# Out:
# R2 Score (Variance Explained): 0.8887
# Mean Absolute Error: $6802.78
# Root Mean Squared Error: $7492.50

# %%
plt.scatter(X_test, y_test, color='red', label='Actual')
plt.plot(X_test, y_pred, color='blue', label='Line of Best Fit')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
# Calculate residuals (errors)
residuals = y_test - y_pred

plt.figure(figsize=(8, 5))
plt.scatter(y_pred, residuals, color='purple', edgecolors='k')
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Salaries')
plt.ylabel('Residuals (Errors)')
plt.title('Residual Plot')
plt.show()
